# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("marketing_campaign_cleaned.csv")
df.head()
# Out:
#    Campaign_ID Campaign_Type        Target_Audience  Duration  \
# 0  NY-CMP-1000  Social Media       College Students        21
# 1  NY-CMP-1001      Paid Ads  Tier 2 City Customers        18
# 2  NY-CMP-1002    Influencer                  Youth        23
# 3  NY-CMP-1003         Email          Working Women        18
# 4  NY-CMP-1004      Paid Ads       College Students        10
#
#                    Channel_Used  Impressions  Clicks  Leads  Conversions  \
# 0             WhatsApp, YouTube        57804    6156   3616         2355
# 1                       YouTube        91801    3321   1971         1357
# 2     WhatsApp, Google, YouTube        15536    2182    952          755
# 3  YouTube, Facebook, Instagram        88114    8413   2231          947
# 4           Facebook, Instagram        96871    3743   2060         1258
#
#    Revenue  Acquisition_Cost   ROI Language  Engagement_Score  \
# 0  1867515            111.03  6.14    Hindi             20.98
# ...

# %%
df.groupby('Campaign_Type')['ROI'].mean().sort_values(ascending = False).plot(kind = 'bar', figsize = (8,5))
plt.title('Average ROI by Campaign type')
plt.xlabel('Campaign type')
plt.ylabel('ROI')
plt.show()

# %%
df[['Acquisition_Cost', 'Revenue', 'ROI']].describe()
# Out:
#        Acquisition_Cost       Revenue           ROI
# count      55555.000000  5.555500e+04  55555.000000
# mean         377.347068  5.158197e+05      2.713807
# std          541.084524  4.900121e+05      4.493380
# min            9.080000  6.183000e+03     -0.970000
# 25%          105.435000  1.777060e+05      0.040000
# 50%          207.510000  3.604360e+05      1.240000
# 75%          428.580000  6.874225e+05      3.630000
# max        15473.160000  4.579910e+06     74.420000

# %%
## Is the company spending marketing budget efficiently?

# %%
plt.figure(figsize =(8,5))
plt.scatter(df['Acquisition_Cost'], df['ROI'])
plt.title('Acquisition Cost VS ROI')
plt.xlabel('Cost')
plt.ylabel('ROI')
plt.show()

# %%
df[['Acquisition_Cost', 'ROI']].corr()
# Out:
#                   Acquisition_Cost       ROI
# Acquisition_Cost          1.000000 -0.370923
# ROI                      -0.370923  1.000000

# %%
(df['ROI'] < 0).sum()
# Out:
# np.int64(13220)

# %%
df.nlargest(10,'ROI')[['Campaign_ID','Campaign_Type','Acquisition_Cost', 'ROI']]
# Out:
#         Campaign_ID Campaign_Type  Acquisition_Cost    ROI
# 12007  NY-CMP-13007      Paid Ads              9.08  74.42
# 21689  NY-CMP-22689    Influencer             10.68  66.32
# 48715  NY-CMP-49715      Paid Ads             12.08  65.00
# 25356  NY-CMP-26356      Paid Ads             10.84  64.14
# 38329  NY-CMP-39329      Paid Ads             12.01  59.64
# 1174    NY-CMP-2174    Influencer             13.72  55.27
# 50204  NY-CMP-51204  Social Media             10.01  54.74
# 4736    NY-CMP-5736         Email              9.85  53.70
# 34197  NY-CMP-35197    Influencer             14.35  52.53
# 23042  NY-CMP-24042  Social Media             13.73  52.45

# %%
df.nsmallest(10,'ROI')[['Campaign_ID','Campaign_Type','Acquisition_Cost', 'ROI']]
# Out:
#         Campaign_ID Campaign_Type  Acquisition_Cost   ROI
# 8361    NY-CMP-9361  Social Media           7187.34 -0.97
# 23406  NY-CMP-24406      Paid Ads           6805.56 -0.97
# 10980  NY-CMP-11980           SEO           7344.84 -0.96
# 13988  NY-CMP-14988         Email           6027.43 -0.96
# 15583  NY-CMP-16583      Paid Ads          12423.65 -0.96
# 23680  NY-CMP-24680  Social Media           5754.04 -0.96
# 35224  NY-CMP-36224  Social Media           5999.57 -0.96
# 40110  NY-CMP-41110         Email           5982.26 -0.96
# 52545  NY-CMP-53545      Paid Ads           6675.92 -0.96
# 54748  NY-CMP-55748         Email           6624.39 -0.96

# %%
df.nlargest(10,'Acquisition_Cost')[['Campaign_ID', 'Acquisition_Cost','ROI','Clicks','Conversions']]
# Out:
#         Campaign_ID  Acquisition_Cost   ROI  Clicks  Conversions
# 33324  NY-CMP-34324          15473.16 -0.95     260           19
# 15583  NY-CMP-16583          12423.65 -0.96     282           20
# 51344  NY-CMP-52344          10920.48 -0.93     318           25
# 2875    NY-CMP-3875           9661.16 -0.93     252           31
# 302     NY-CMP-1302           9469.83 -0.93     247           24
# 22760  NY-CMP-23760           9438.00 -0.95     266           26
# 49497  NY-CMP-50497           8983.24 -0.95     281           29
# 53089  NY-CMP-54089           8703.74 -0.95     434           34
# 19609  NY-CMP-20609           8686.46 -0.95     322           28
# 27468  NY-CMP-28468           8414.39 -0.92     270           28

# %%
## Why are users clicking but not converting?

# %%
plt.figure(figsize =(8,5))
plt.scatter(df['Clicks'], df['Conversions'])
plt.title('Clicks VS Conversions')
plt.xlabel('Numbe of Clicks')
plt.ylabel('Number of Conversions')
plt.show()

# %%
plt.figure(figsize= (8,5))
plt.scatter(df['Clicks'], df['ROI'])
plt.title('Clicks VS ROI')
plt.xlabel('Number of clicks')
plt.ylabel('ROI')
plt.show()

# %%
df[['Clicks', 'Conversions', 'ROI','Engagement_Score']].corr()
# Out:
#                     Clicks  Conversions       ROI  Engagement_Score
# Clicks            1.000000     0.815915  0.559149          0.627942
# Conversions       0.815915     1.000000  0.688136          0.643408
# ROI               0.559149     0.688136  1.000000          0.444604
# Engagement_Score  0.627942     0.643408  0.444604          1.000000

# %%
df.nlargest(10, 'Clicks')[['Campaign_ID', 'Clicks', 'Conversions', 'ROI']]
# Out:
#         Campaign_ID  Clicks  Conversions    ROI
# 227     NY-CMP-1227   14868         4926  45.77
# 45745  NY-CMP-46745   14868         4863  12.05
# 31303  NY-CMP-32303   14840         3191   3.05
# 48960  NY-CMP-49960   14827         1108   1.00
# 34279  NY-CMP-35279   14820         2864  12.00
# 29911  NY-CMP-30911   14789         2697  10.07
# 31723  NY-CMP-32723   14745         1643  20.52
# 27840  NY-CMP-28840   14734         2148   4.94
# 49048  NY-CMP-50048   14708         3641   6.64
# 52809  NY-CMP-53809   14708         1852   4.75

# %%
median_clicks = df['Clicks'].median()
high_click_low_conversion = df[(df['Clicks'] > median_clicks) & (df['Conversions'] < df['Conversions'].median()) ]

# %%
high_click_low_conversion
# Out:
#         Campaign_ID Campaign_Type        Target_Audience  Duration  \
# 11      NY-CMP-1011           SEO                  Youth         7
# 28      NY-CMP-1028      Paid Ads                  Youth        15
# 79      NY-CMP-1079      Paid Ads       Premium Shoppers        17
# 95      NY-CMP-1095      Paid Ads          Working Women        29
# 114     NY-CMP-1114  Social Media  Tier 2 City Customers        27
# ...             ...           ...                    ...       ...
# 55526  NY-CMP-56526      Paid Ads  Tier 2 City Customers        15
# 55539  NY-CMP-56539  Social Media          Working Women        30
# 55542  NY-CMP-56542    Influencer  Tier 2 City Customers        14
# 55544  NY-CMP-56544           SEO       College Students        10
# 55545  NY-CMP-56545    Influencer       College Students         8
#
#                        Channel_Used  Impressions  Clicks  Leads  Conversions  \
# 11                Facebook, YouTube        39696    5623   1136          661
# ...

# %%
plt.figure(figsize= (8,5))
plt.hist(df['Conversions'], bins = 20)
plt.title('Distribution of conversions')
plt.xlabel('Conversions')
plt.ylabel('Number of campaigns')
plt.show()

# %%
## What factors influence campaign success?

# %%
df.describe()
# Out:
#            Duration    Impressions        Clicks         Leads   Conversions  \
# count  55555.000000   55555.000000  55555.000000  55555.000000  55555.000000
# mean      17.446044   55087.885357   4688.070507   1877.271119   1032.866925
# std        7.520438   25930.001514   3178.686285   1435.636117    862.496788
# min        5.000000   10001.000000    202.000000     56.000000     19.000000
# 25%       11.000000   32680.000000   2110.000000    779.000000    400.000000
# 50%       17.000000   55182.000000   3907.000000   1481.000000    779.000000
# 75%       24.000000   77514.500000   6688.000000   2605.000000   1414.000000
# max       30.000000  100000.000000  14868.000000   8876.000000   6686.000000
#
#             Revenue  Acquisition_Cost           ROI  Engagement_Score
# count  5.555500e+04      55555.000000  55555.000000      55555.000000
# mean   5.158197e+05        377.347068      2.713807         13.784169
# ...

# %%
plt.figure(figsize = (8,5))
plt.scatter(df['Engagement_Score'], df['ROI'])
plt.title('Engagement score vs ROI')
plt.xlabel('Score')
plt.ylabel('ROI')
plt.show()

# %%
df[['Engagement_Score','ROI']].corr()
# Out:
#                   Engagement_Score       ROI
# Engagement_Score          1.000000  0.444604
# ROI                       0.444604  1.000000

# %%
plt.figure(figsize = (8,5))
plt.scatter(df['Impressions'], df['Clicks'])
plt.title('Impressions VS clicks')
plt.xlabel('Impressions')
plt.ylabel('Clicks')
plt.show()

# %%
df[['Impressions', 'Clicks']].corr()
# Out:
#              Impressions    Clicks
# Impressions     1.000000  0.693781
# Clicks          0.693781  1.000000

# %%
plt.figure(figsize = (8,5))
plt.scatter(df['Impressions'], df['Conversions'])
plt.title('Impressions VS conversions')
plt.xlabel('Impressions')
plt.ylabel('Conversions')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.scatter(df['Duration'], df['ROI'])
plt.show()

# %%
df.groupby('Customer_Segment')['ROI'].mean().sort_values(ascending = False).plot(kind= 'bar', figsize =(8,5))
plt.title('Avg ROI by customer segment')
plt.xlabel('Customer segment')
plt.ylabel('ROI')
plt.show()

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Year'] = df['Date'].dt.yeat

# %%
df.groupby('Year')['ROI'].mean().plot(kind = 'line',marker ='o', figsize= (8,5))
plt.title('Avg ROI by Year')
plt.ylabel('ROI')
plt.show()

# %%
df.groupby('Year')['Conversions'].sum().plot(kind = 'line', marker ='o', figsize =(8,5))
plt.title('Total conversions by year')
plt.ylabel('conversions')
plt.show()
